# %% [markdown]
# <a href="https://colab.research.google.com/github/ajinfajrian/data-science-2026/blob/master/Pertemuan1_240401020100_Fajrian_Ichlasul.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
nama = "Fajrian Ichlasul"
angkatan = 2024
print(f"Halo, {nama} angkatan {angkatan}!")
# Out:
# Halo, Fajrian Ichlasul angkatan 2024!

# %%
tools = ["Python", "Colab", "Jupyter", "GitHub"]
for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
# Out:
# 1. Python
# 2. Colab
# 3. Jupyter
# 4. GitHub
